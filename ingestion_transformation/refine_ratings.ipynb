# %% [markdown]
# ### Overview
# A minimal preprocessing notebook that performs a simple format conversion of ratings data from CSV to Parquet format. This notebook is intentionally brief as the ratings data was already cleaned or standardized in a previous step.

# %%
import pandas as pd

pd.read_csv("ratings_edit.csv").to_parquet("ratings_edit.parquet")
